# %%
# !python babynames_Rahul.py --summaryfile baby2004.html

# %%
# !python EDIMasking-work.py --maskfile SampleEDI.edi
# Out:
# NM1*41*2*James Health Center*****46*90732421~
#
# NM1*41*2*Alexandra Hayward Research*****46*90732421~
#
# NM1*41*2*James Health Center*****46*90732421~
#
# NM1*41*2*Alexandra Hayward Research*****46*90732421~
#
# NM1*IL*1*Smith*Mary****MI*8A9B1C3D9E1~
#
# NM1*IL*1*Tran*Van****MI*8A9B1C3D9E1~
#
# NM1*IL*1*SMITH*MARY****MI*8a9b1c3d9e1~
#
# NM1*IL*1*Tran*Van****MI*8a9b1c3d9e1~
#
# N3*192 ABC Rd.*~
#
# N3*7530 Pearl Ave.~
#
# N3*192 ABC Rd.*~
#
# N3*7530 Pearl Ave.~
#
# N4*CoolCity*AZ*283918301~
#
# N4*Bridgeport*AZ*283279791~
#
# N4*CoolCity*AZ*283918301~
#
# N4*Bridgeport*AZ*283279791~
#
# N4*CoolCity*AZ*46384~
#
# N4*Bridgeport*AZ*46315~
#
# REF*EI*817283948~
#
# REF*EI*100700521~
#
# REF*EI*817283948~
#
# REF*EI*100700521~
#
# DMG*D8*47281921*F~
#
# DMG*D8*47281914*F~
#
# DMG*D8*47281921*F~
#
# DMG*D8*47281914*F~
#
# ISA*00*          *00*          *ZZ*90732421       *ZZ*55589          *200122*1900*^*00501*000000856*1*T*:~
#
# ...
